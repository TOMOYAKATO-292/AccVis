# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       OCCURRENCE_DATE_AND_TIME WEATHER                        LOCATION  \
# 0          2019-01-01 08:00:00      晴れ                       泉佐野市泉州空港北
# 1          2019-01-01 08:56:00       曇  東北上り３６９．６（路肩）【宮城県大崎市三本木新沼舞台付近】
# 2          2019-01-01 13:55:00      晴れ                       瀬戸市陶本町２丁目
# 3          2019-01-01 15:20:00      晴れ                       京都市中京区中島町
# 4          2019-01-01 17:08:00      晴れ                           富津市亀沢
# ...                        ...     ...                             ...
# 19887      2023-12-30 16:10:00      晴れ                         北区豊島６−８
# 19888      2023-12-31 02:45:00       雨                   新城市矢部ユツリハ８１−２
# 19889      2023-12-31 06:37:00       雨                  富里市根木名１０３８−７番地
# 19890      2023-12-31 17:30:00       雨     奥州市前沢養ヶ森２７−６　東北道前沢ＳＡ下り入り口車線
# 19891      2023-12-31 18:41:00      晴れ                   札幌市中央区大通東１丁目３
#
#        LATITUDE  LONGITUDE ACCIDENT_TYPE_(CATEGORY)     ROAD_TYPE  \
# ...

# %%
df1 = df[['LATITUDE','LONGITUDE','ACCIDENT_TYPE_(CATEGORY)','ROAD_TYPE','WEATHER','VEHICLE_1:_BODY_TYPE']]
df1
# Out:
#        LATITUDE  LONGITUDE ACCIDENT_TYPE_(CATEGORY)     ROAD_TYPE WEATHER  \
# 0      34.44694  135.24103                     健康起因  道路(自動車専用道路等)      晴れ
# 1      40.72787  141.25789                     車両故障   道路(高速自動車国道)       曇
# 2      35.22557  137.09769                     健康起因        その他の場所      晴れ
# 3      35.00894  135.77055                     車両故障       道路(その他)      晴れ
# 4      35.27262  139.90591                       衝突   道路(高速自動車国道)      晴れ
# ...         ...        ...                      ...           ...     ...
# 19887  35.76449  139.74539                     健康起因       道路(その他)      晴れ
# 19888  34.92282  137.50938                     車両故障        その他の場所       雨
# 19889  35.73569  140.34648                     車両故障       道路(その他)       雨
# 19890  39.06780  141.10068                     車両故障   道路(高速自動車国道)       雨
# 19891  43.06237  141.35744                     車両故障        その他の場所      晴れ
#
#       VEHICLE_1:_BODY_TYPE
# 0                       箱型
# ...

# %%
df1.to_csv("economic_impact.csv", index=False, encoding='utf-8-sig')

# %%
df1
# Out:
#        LATITUDE  LONGITUDE ACCIDENT_TYPE_(CATEGORY)     ROAD_TYPE WEATHER  \
# 0      34.44694  135.24103                     健康起因  道路(自動車専用道路等)      晴れ
# 1      40.72787  141.25789                     車両故障   道路(高速自動車国道)       曇
# 2      35.22557  137.09769                     健康起因        その他の場所      晴れ
# 3      35.00894  135.77055                     車両故障       道路(その他)      晴れ
# 4      35.27262  139.90591                       衝突   道路(高速自動車国道)      晴れ
# ...         ...        ...                      ...           ...     ...
# 19887  35.76449  139.74539                     健康起因       道路(その他)      晴れ
# 19888  34.92282  137.50938                     車両故障        その他の場所       雨
# 19889  35.73569  140.34648                     車両故障       道路(その他)       雨
# 19890  39.06780  141.10068                     車両故障   道路(高速自動車国道)       雨
# 19891  43.06237  141.35744                     車両故障        その他の場所      晴れ
#
#       VEHICLE_1:_BODY_TYPE
# 0                       箱型
# ...
